# %%
import random
import getpass
import openpyxl
import funcionesf as ff
    
print('--Bienvenido al juego de adivinanza--')
print()
print()

m=0
while m==0:
    print('Favor de seleccionar el modo de juego deseado:')
    print()
    print('  1. Partida modo Solitario \n  2. Partida 2 Jugadores \n  3. Estadística \n  4. Salir')
    print()
    modojueg=ff.validar(1,4)
    if modojueg==1 or modojueg ==2:
        print()
        print('------------------------------------------------------------------')
        print()
        print('Perfecto! Que modo de juego te gustaria jugar?')
        print()
        print('  1. Fácil (20 intentos) \n  2. Medio (12 Intentos) \n  3. Difícil (5 intentos)')
        print()
        mododificultad=ff.validar(1,3)
        if mododificultad==1:
            vidas=20
        if mododificultad==2:
            vidas=12
        if mododificultad==3:
            vidas=5
        print()
        print('------------------------------------------------------------------')
        print()    
        if modojueg==1:
            numeroadivinar=random.randint(1,1000)
            print('Listo! ya tengo tu numero listo, podemos comenzar el juego.')
            print()
            resultado, intentos, nomb = ff.juego(vidas,numeroadivinar)
            ff.exportardatos(nomb, intentos, resultado)
            
        else:
            print('Escribe un número para que el jugador 2 adivine.')
            print()
            numeroadivinar=ff.validaroculto(1,1000)
            print()
            print('Perfecto! ya tenemos todo listo, ahora sí podemos comenzar el juego.')
            print()
            print('-Ahora es turno del jugador 2.')
            print()
            resultado, intentos, nomb = ff.juego(vidas,numeroadivinar)
            ff. exportardatos(nomb, intentos, resultado)
           
    if modojueg == 3:
        ff.estadist()
                
    if modojueg == 4:
        print()
        print('Excelente, nos vemos pronto, gracias por jugar!!!')
        m=1
# Out:
# --Bienvenido al juego de adivinanza--
#
#
# Favor de seleccionar el modo de juego deseado:
#
#   1. Partida modo Solitario
#   2. Partida 2 Jugadores
#   3. Estadística
#   4. Salir
# Escribe una opcion entre 1 y 4: 1
# ------------------------------------------------------------------
#
# Perfecto! Que modo de juego te gustaria jugar?
#
#   1. Fácil (20 intentos)
#   2. Medio (12 Intentos)
#   3. Difícil (5 intentos)
# Escribe una opcion entre 1 y 3: 2
# ------------------------------------------------------------------
#
# Listo! ya tengo tu numero listo, podemos comenzar el juego.
# Trata de adivinar el número: 500
# -No, el numero que buscas es menor!
#
# (Recuerda que te quedan 11 vidas)
# Trata de adivinar el número: 250
# -NOO, el numero que buscas es mayor!
#
# (Recuerda que te quedan 10 vidas)
# Trata de adivinar el número: 320
# -No, el numero que buscas es menor!
#
# (Recuerda que te quedan 9 vidas)
# Trata de adivinar el número: 285
# -NOO, el numero que buscas es mayor!
#
# (Recuerda que te quedan 8 vidas)
# Trata de adivinar el número: 300
# -NOO, el numero que buscas es mayor!
#
# (Recuerda que te quedan 7 vidas)
# Trata de adivinar el número: 310
# -No, el numero que buscas es menor!
#
# (Recuerda que te quedan 6 vidas)
# Trata de adivinar el número: 305
# -NOO, el numero que buscas es mayor!
#
# (Recuerda que te quedan 5 vidas)
# Trata de adivinar el número: 307
# -NOO, el numero que buscas es mayor!
#
# (Recuerda que te quedan 4 vidas)
# Trata de adivinar el número: 308
# ************************************************************
#           SIIII!!!!, acertaste el numero era 308
# ************************************************************
#
# Ahora por favor dame tu nombre para registrar tus datos
# Nombre: Miguel
# --Perfecto Miguel tus datos se han guardado correctamente!
#
# Gracias por Jugar!!
#
# ------------------------------------------------------------------
#
# Favor de seleccionar el modo de juego deseado:
#
#   1. Partida modo Solitario
#   2. Partida 2 Jugadores
#   3. Estadística
#   4. Salir
# Escribe una opcion entre 1 y 4: 3
# ------------------------------------------------------------------
#
# A continuación te muestro una tabla con los datos de los jugadores:
#
# Nombre | Intentos | Resultado |
# Vicky | 4 | gano |
# Miguel | 2 | gano |
# Manuel | 5 | perdio |
# Victoria | 3 | gano |
# Vickycars | 8 | gano |
# Miguel.castr | 11 | Gano |
# Vickycars | 10 | Gano |
# MiguelAn | 3 | Gano |
# miguelac | 1 | Gano |
# VIC | 10 | Gano |
# Victoria Cars | 6 | Perdio |
# Miguel Castrol | 4 | Gano |
# Miguel | 9 | Gano |
#
# ------------------------------------------------------------------
#
# Favor de seleccionar el modo de juego deseado:
#
#   1. Partida modo Solitario
#   2. Partida 2 Jugadores
#   3. Estadística
#   4. Salir
# Escribe una opcion entre 1 y 4: 8
# **Valor Erroneo, recuerda que tu numero debe estar entre 1 y 4
# Escribe una opcion entre 1 y 4: 0
# **Valor Erroneo, recuerda que tu numero debe estar entre 1 y 4
# Escribe una opcion entre 1 y 4: 3
# ------------------------------------------------------------------
#
# A continuación te muestro una tabla con los datos de los jugadores:
#
# Nombre | Intentos | Resultado |
# Vicky | 4 | gano |
# Miguel | 2 | gano |
# Manuel | 5 | perdio |
# Victoria | 3 | gano |
# Vickycars | 8 | gano |
# Miguel.castr | 11 | Gano |
# Vickycars | 10 | Gano |
# MiguelAn | 3 | Gano |
# miguelac | 1 | Gano |
# VIC | 10 | Gano |
# Victoria Cars | 6 | Perdio |
# Miguel Castrol | 4 | Gano |
# Miguel | 9 | Gano |
#
# ------------------------------------------------------------------
#
# Favor de seleccionar el modo de juego deseado:
#
#   1. Partida modo Solitario
#   2. Partida 2 Jugadores
#   3. Estadística
#   4. Salir
# Escribe una opcion entre 1 y 4: 4
# Excelente, nos vemos pronto, gracias por jugar!!!
